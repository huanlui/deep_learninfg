# %% [markdown]
# # Introduction to Neural Networks and Deep Learning

# %% [markdown]
# ## What's the difference between Artificial Intelligence, Machine Learning and Deep Learning?
#
# **Artificial Intelligence** (AI) is a very old field of research. It started in the 1950s; at that time, the pioneers in AI were convinced that they could make machines think. The initial approach was attempting to model intellectual tasks, and program those tasks in computers. That is, in the beginning, AI was about people *hard-coding* problems that the machine tried to solve. A good example of an early AI program is computer chess. Early AI computer chess programs had **lots of rules pre-conceived by the program designers**. So although the term refers to "intelligence", these programs were not "intelligent", but just a sophisticated set of rules.
#
# * The term *neural network* was also born at that time. The initial idea was trying to mimic how a *neuron* works (or in fact, how it was thought a neuron worked when the term was coined) in the brain. As in the case of *Artificial Intelligence*, please do not be fooled by the terms. A *neural network* is just a way to compute approximation to functions. A powerful and useful way, true. But it is not any kind of "artificial brain", or anything like that.
#
# This approach is now obsolete. We now know that some tasks are so complex, that we will never be able to pre-design a system to have a good performance on those tasks. Take the example of the game of Go. Any program designed by humans to play Go was dull and could not compete against professional players. The game is so hard that is just impossible for us as humans to conceived a good Go computer player.
# * https://en.wikipedia.org/wiki/Go_(game)
#
# The modern approach to solve this kind of problems involves the use of data. This is what the *learning* part of *Deep Learning* (and *Machine Learning*) refers to. **Learning from data**. So, with this brief introduction, we can say that *Artificial Intelligence* is a broad concept that includes *Machine Learning*, that includes *Deep Learning*. *Artificial Intelligence* does not necessarily means learning from data, but Machine Learning does. And *Deep Learning* is just doing *Machine Learning* with neural networks.
#
# ![](imgs/01_ai_ml_dl.png)
#
# We will see during this course what *learning* means, and what is a *neural network*.
#
# In the case of the game of Go, all attempts to design a good Go computer player failed, until Google DeepMind created AlphaGo, a system that *learned* to play Go based on data from previous games. AlphaGo is an example that learning from data can provide computer systems that are superior to any system pre-conceived by humans.
# * Find out more about AlphaGo by watching this utterly interesting movie: https://www.alphagomovie.com/
#
# In this course, we will give our first steps on *Deep Learning* and *Neural Networks*, to start creating systems that perform complex tasks by learning from data. Instead of attempting to derive the rules by ourselves, those rules will be inferred by a neural network based on the data we provide:
#
# ![](imgs/02_rules_data.png)

# %% [markdown]
# # Deep Learning and Machine Learning: why is everyone now talking about Deep Learning?
#
# To create our system, we need data:
# * Input data points; e.g. images to recognize shapes inside the images.
# * Examples of expected output. The system will use these examples to learn from them. For the images above, we will need *labels* telling us what is in the image.
#
# The neural network will *learn* from this data. But in fact, what the network is doing is learning a *representation* of the data that makes the task much easier to solve.
#
# Let's see an example. We have the following input data (x,y coordinates for the points), and the labels of each item (the color of the point). We would like to obtain a model to separete the two classes of points:
#
# ![](imgs/03_points.png)
#
# How would you separate the points? In the current reference system, it can be a complex task. But if you change the reference system (*if you learn a new representation of the data*), the task becomes trivial:
#
# ![](imgs/04_representation.png)
#
# In Deep Learning, we learn **layers** of increasingly better representations. The **deep** in Deep Learning refers to the number of layers that we learn. Before Deep Learning, the models that we are going to see today were much shallower. The most typical form of the layer representations is **neural networks**. As we will see, **neural networks** are just chain of matrix operations -- arrays of 2 dimensions--, or more precisely, tensor operations, we will operate in dimensions higher than 2.
#
#
# * More about learning representations: https://www.bbvadata.com/not-deep-learning-learning-represent/

# %% [markdown]
# ## Neural Networks
#
# A neural network is just a stacked set of layers. Each layer is represented by a tensor, and it performs an affine transformation on each one of the layers.
# * A matrix is a 2D tensor
# * Affine transformation $\vec{y} = W\cdot\vec{x} + \vec{b}$, where $W$ is the weights tensor, $\vec{x}$ is the input data, $\vec{y}$ is the output data and $\vec{b}$ is called the bias
# * $W$ and $\vec{b}$ are model parameters that need to be found by training
#
# ![](imgs/05_nn.png)
#
# Note that this is a **linear operation**, therefore the result will be linear too. But the functions we want to learn are normally non-linear. How do we overcome this limiation? By using an **activation function**, that transforms the result from the linear operation. So, we actually do the following operation:
#
# $\vec{y} = f\left(W\cdot\vec{x} + \vec{b}\right)$
#
# There are several common activation functions, depending on the characteristics of the data and the kind of problem we want to solve. Here we will use the probably most often used activation function: **rectified linear unit**, or **relu** for friends:
#
# ![Relu plot](https://upload.wikimedia.org/wikipedia/commons/6/6c/Rectifier_and_softplus_functions.svg)
#
# (image extracted from https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Relu will add the non-linearity that we need to learn arbitrary functions.
#
# We can achieve the same with many other activation functions. See the documentation of Keras for details on the available activation functions:
#  - https://keras.io/activations/
#
#
# Each layer learns a new representation of the input data, and after several layers, the representation will make it straightforward to solve the task (e.g. assiging a digit to an image of a digit).
#
# Until very recently, any attempt to train a deep neural network would not provide good results. Recent progresses (e.g. advances in hardware, new activation functions) make it possible to train very deep network, and therefore, solve problems that were unfeasible not long ago.
#
# ### Training process
#
# The parameters of the network are initially randomly assigned. Then after each pass of the network, that is, after each *epoch*, the predictions of the network is compared against the true values, applying a *loss function*. This score is used to update the parameters of the network, with a process called **backpropagation**.
# * Backpropagation is a complex process that involves calculating the gradient of the parameters of the network. For more details see: https://en.wikipedia.org/wiki/Backpropagation
# * See also this excellent and visual explanation of how backpropagation works: https://google-developers.appspot.com/machine-learning/crash-course/backprop-scroll/
#
# The training process is just an optimization process, that is normally done using a gradient descent-based algorithm. The values of gradients are computed using the backpropagation algorithm. Each epoch will make the loss score to be lower, and the predictions to be better.
#
# ![](imgs/06_optim.png)
#
# In practice, we have to fine tune the number of epochs (and other parameters), until we obtain a result that is good enough for our purpose. In fact, if the number of epochs is too high, our model may **overfit** the training data. In that case, it will perform worsely when the model is exposed to data that it  has not seen previously.
# * Fine tuning the number of epochs, and other parameters (e.g. the number and shape of the layers) is known as **hyperparameters optimization**, or **hyperparameters tuning**
# * The parameters of the model are the $W$ and $b$ values of each layer, and those are determined by training.
#
# ## Hyperparameters tuning
#
# In summary, when we are trying to obtain a deep learning model, the process that we will follow is:
# * Decide on the architecture of the network (number of layers, type of each layer, size of each layer)
# * Decide on the activation functions on each layer
# * Decide on the parameters related to the optimization process (e.g. learning rate)
# * Decide on the loss function that we will use
# * Decide on the metrics that we will use to evaluate the performance of the model
# * Decide on the training parameters (number of epochs, batch size)
# * Decide on how to split the data between training, validation and test sets.
#
# We obtain feedback for those decisions with the results of the training applied to the validation set. We train once, change some of the hyperparameters, train again, decide if that's better, and we keep going until we have found a model that is satisfactory enough for our purposes.
#
# After that, we finally evaluate the model on the test set.

# %% [markdown]
# ## Our first neural network
#
# Let's start with an easy example. We are going to produce some synthetic data, and will try to predict the function that generates the data. We will add some noise, to make the problem more difficult.
#
# The function we are going to try to predict is
#
# $\displaystyle y = 3*x + 2$

# %%
# %pylab inline
plt.style.use('seaborn-talk')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_metric(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.show()

# %% [markdown]
# ### Preparar los datos

# %%
x_train = np.linspace(0, 100, 1000)
y_train = 3*x_train + 2

x_test = np.linspace(100.01, 110, 100)
y_test = 3*x_test + 2

# %%
plot(x_train, y_train, 'b')
plot(x_test, y_test, 'r')

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras import models
from keras import layers

# %%
m = models.Sequential()
capa_oculta = layers.Dense(units=64, input_shape=(1,))
m.add(capa_oculta)
salida = layers.Dense(units=1)
m.add(salida)
m.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                128
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
m = models.Sequential()
m.add(layers.Dense(units=128, input_shape=(1,), activation='relu'))
m.add(layers.Dense(units=64, activation='relu'))
m.add(layers.Dense(units=32, activation='relu'))
m.add(layers.Dense(units=16, activation='relu'))
m.add(layers.Dense(units=1, activation='relu'))

m.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               256
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
from keras import losses
from keras import metrics

# %%
m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
h = m.fit(x_train, y_train, batch_size=100, epochs=80, validation_split=0.2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 800 samples, validate on 200 samples
# Epoch 1/80
# 800/800 [==============================] - 5s 6ms/step - loss: 18356.0699 - mean_absolute_error: 117.8140 - val_loss: 64454.6445 - val_mean_absolute_error: 253.3656
# Epoch 2/80
# 800/800 [==============================] - 0s 39us/step - loss: 15797.0267 - mean_absolute_error: 109.2644 - val_loss: 52875.8301 - val_mean_absolute_error: 229.4826
# Epoch 3/80
# 800/800 [==============================] - 0s 36us/step - loss: 12241.3569 - mean_absolute_error: 96.2126 - val_loss: 36960.0039 - val_mean_absolute_error: 191.8616
# Epoch 4/80
# 800/800 [==============================] - 0s 49us/step - loss: 7816.1841 - mean_absolute_error: 76.5845 - val_loss: 19749.4111 - val_mean_absolute_error: 140.2494
# Epoch 5/80
# 800/800 [==============================] - 0s 36us/step - loss: 3514.9694 - mean_absolute_error: 51.1256 - val_loss: 6192.2974 - val_mean_absolute_error: 78.5335
# Epoch 6/80
# 800/800 [==============================] - 0s 34us/step - loss: 842.3524 - mean_absolute_error: 24.3423 - val_loss: 668.6088 - val_mean_absolute_error: 25.8071
# Epoch 7/80
# 800/800 [==============================] - 0s 34us/step - loss: 61.7962 - mean_absolute_error: 6.1432 - val_loss: 7.4203 - val_mean_absolute_error: 2.7204
# Epoch 8/80
# 800/800 [==============================] - 0s 34us/step - loss: 0.6515 - mean_absolute_error: 0.6294 - val_loss: 0.0854 - val_mean_absolute_error: 0.2876
# Epoch 9/80
# 800/800 [==============================] - 0s 35us/step - loss: 0.0675 - mean_absolute_error: 0.2154 - val_loss: 0.1243 - val_mean_absolute_error: 0.3483
# Epoch 10/80
# 800/800 [==============================] - 0s 32us/step - loss: 0.0656 - mean_absolute_error: 0.2122 - val_loss: 0.1607 - val_mean_absolute_error: 0.3967
# Epoch 11/80
# 800/800 [==============================] - 0s 34us/step - loss: 0.0643 - mean_absolute_error: 0.2112 - val_loss: 0.0654 - val_mean_absolute_error: 0.2513
# Epoch 12/80
# 800/800 [==============================] - 0s 37us/step - loss: 0.0622 - mean_absolute_error: 0.2072 - val_loss: 0.0054 - val_mean_absolute_error: 0.0646
# Epoch 13/80
# 800/800 [==============================] - 0s 37us/step - loss: 13.7545 - mean_absolute_error: 2.3576 - val_loss: 117.7098 - val_mean_absolute_error: 10.8293
# Epoch 14/80
# 800/800 [==============================] - 0s 36us/step - loss: 5.6529 - mean_absolute_error: 1.4701 - val_loss: 1.8240 - val_mean_absolute_error: 1.3494
# Epoch 15/80
# 800/800 [==============================] - 0s 34us/step - loss: 12.3146 - mean_absolute_error: 2.4917 - val_loss: 66.9433 - val_mean_absolute_error: 8.1671
# Epoch 16/80
# 800/800 [==============================] - 0s 38us/step - loss: 4.6510 - mean_absolute_error: 1.7359 - val_loss: 13.4639 - val_mean_absolute_error: 3.6636
# Epoch 17/80
# 800/800 [==============================] - 0s 33us/step - loss: 13.4394 - mean_absolute_error: 3.0342 - val_loss: 40.7986 - val_mean_absolute_error: 6.3762
# Epoch 18/80
# 800/800 [==============================] - 0s 37us/step - loss: 4.4651 - mean_absolute_error: 1.7916 - val_loss: 29.8080 - val_mean_absolute_error: 5.4503
# Epoch 19/80
# 800/800 [==============================] - 0s 36us/step - loss: 12.9786 - mean_absolute_error: 3.0987 - val_loss: 16.1691 - val_mean_absolute_error: 4.0146
# Epoch 20/80
# 800/800 [==============================] - 0s 37us/step - loss: 5.1144 - mean_absolute_error: 1.9312 - val_loss: 65.0326 - val_mean_absolute_error: 8.0496
# Epoch 21/80
# 800/800 [==============================] - 0s 38us/step - loss: 10.8698 - mean_absolute_error: 2.7360 - val_loss: 18.5247 - val_mean_absolute_error: 4.2969
# Epoch 22/80
# 800/800 [==============================] - 0s 33us/step - loss: 10.0379 - mean_absolute_error: 2.7168 - val_loss: 40.0752 - val_mean_absolute_error: 6.3193
# Epoch 23/80
# 800/800 [==============================] - 0s 33us/step - loss: 7.4986 - mean_absolute_error: 2.3184 - val_loss: 13.3925 - val_mean_absolute_error: 3.6537
# Epoch 24/80
# 800/800 [==============================] - 0s 33us/step - loss: 11.3487 - mean_absolute_error: 2.8247 - val_loss: 17.9793 - val_mean_absolute_error: 4.2331
# Epoch 25/80
# 800/800 [==============================] - 0s 40us/step - loss: 5.3698 - mean_absolute_error: 2.0134 - val_loss: 34.7689 - val_mean_absolute_error: 5.8861
# Epoch 26/80
# 800/800 [==============================] - 0s 36us/step - loss: 11.3883 - mean_absolute_error: 2.8544 - val_loss: 7.3439 - val_mean_absolute_error: 2.7059
# Epoch 27/80
# 800/800 [==============================] - 0s 35us/step - loss: 6.2597 - mean_absolute_error: 2.0451 - val_loss: 68.4665 - val_mean_absolute_error: 8.2591
# Epoch 28/80
# 800/800 [==============================] - 0s 33us/step - loss: 10.9761 - mean_absolute_error: 2.8602 - val_loss: 27.2567 - val_mean_absolute_error: 5.2116
# Epoch 29/80
# 800/800 [==============================] - 0s 32us/step - loss: 5.9856 - mean_absolute_error: 2.1146 - val_loss: 29.1914 - val_mean_absolute_error: 5.3933
# Epoch 30/80
# 800/800 [==============================] - 0s 34us/step - loss: 12.3110 - mean_absolute_error: 2.9743 - val_loss: 10.7452 - val_mean_absolute_error: 3.2727
# Epoch 31/80
# 800/800 [==============================] - 0s 36us/step - loss: 4.2245 - mean_absolute_error: 1.7650 - val_loss: 41.5251 - val_mean_absolute_error: 6.4322
# Epoch 32/80
# 800/800 [==============================] - 0s 34us/step - loss: 11.3458 - mean_absolute_error: 2.8566 - val_loss: 14.4476 - val_mean_absolute_error: 3.7946
# Epoch 33/80
# 800/800 [==============================] - 0s 39us/step - loss: 7.9881 - mean_absolute_error: 2.3874 - val_loss: 48.1222 - val_mean_absolute_error: 6.9242
# Epoch 34/80
# 800/800 [==============================] - 0s 30us/step - loss: 8.5817 - mean_absolute_error: 2.5163 - val_loss: 20.5850 - val_mean_absolute_error: 4.5291
# Epoch 35/80
# 800/800 [==============================] - 0s 35us/step - loss: 7.3261 - mean_absolute_error: 2.3355 - val_loss: 40.1278 - val_mean_absolute_error: 6.3230
# Epoch 36/80
# 800/800 [==============================] - 0s 38us/step - loss: 10.3910 - mean_absolute_error: 2.7857 - val_loss: 26.3382 - val_mean_absolute_error: 5.1228
# Epoch 37/80
# 800/800 [==============================] - 0s 38us/step - loss: 8.0670 - mean_absolute_error: 2.4423 - val_loss: 11.7310 - val_mean_absolute_error: 3.4192
# Epoch 38/80
# 800/800 [==============================] - 0s 36us/step - loss: 8.6723 - mean_absolute_error: 2.5180 - val_loss: 45.2175 - val_mean_absolute_error: 6.7119
# Epoch 39/80
# 800/800 [==============================] - 0s 37us/step - loss: 7.3042 - mean_absolute_error: 2.2665 - val_loss: 34.8264 - val_mean_absolute_error: 5.8905
# Epoch 40/80
# 800/800 [==============================] - 0s 44us/step - loss: 10.2014 - mean_absolute_error: 2.7162 - val_loss: 11.1561 - val_mean_absolute_error: 3.3344
# Epoch 41/80
# 800/800 [==============================] - 0s 33us/step - loss: 8.5597 - mean_absolute_error: 2.4534 - val_loss: 28.6604 - val_mean_absolute_error: 5.3438
# Epoch 42/80
# 800/800 [==============================] - 0s 33us/step - loss: 7.7724 - mean_absolute_error: 2.4022 - val_loss: 18.2792 - val_mean_absolute_error: 4.2678
# Epoch 43/80
# 800/800 [==============================] - 0s 33us/step - loss: 8.6234 - mean_absolute_error: 2.5003 - val_loss: 13.2067 - val_mean_absolute_error: 3.6277
# Epoch 44/80
# 800/800 [==============================] - 0s 44us/step - loss: 9.7949 - mean_absolute_error: 2.6243 - val_loss: 45.1528 - val_mean_absolute_error: 6.7070
# Epoch 45/80
# 800/800 [==============================] - 0s 40us/step - loss: 5.9001 - mean_absolute_error: 2.0722 - val_loss: 51.5301 - val_mean_absolute_error: 7.1649
# Epoch 46/80
# 800/800 [==============================] - 0s 36us/step - loss: 11.8075 - mean_absolute_error: 2.9488 - val_loss: 11.8265 - val_mean_absolute_error: 3.4329
# Epoch 47/80
# 800/800 [==============================] - 0s 37us/step - loss: 5.6867 - mean_absolute_error: 2.0634 - val_loss: 20.1710 - val_mean_absolute_error: 4.4830
# Epoch 48/80
# 800/800 [==============================] - 0s 34us/step - loss: 11.2147 - mean_absolute_error: 2.8756 - val_loss: 21.3741 - val_mean_absolute_error: 4.6147
# Epoch 49/80
# 800/800 [==============================] - 0s 36us/step - loss: 5.7435 - mean_absolute_error: 2.0595 - val_loss: 18.1657 - val_mean_absolute_error: 4.2543
# Epoch 50/80
# 800/800 [==============================] - 0s 34us/step - loss: 10.5152 - mean_absolute_error: 2.7688 - val_loss: 33.0200 - val_mean_absolute_error: 5.7355
# Epoch 51/80
# 800/800 [==============================] - 0s 34us/step - loss: 6.4412 - mean_absolute_error: 2.1554 - val_loss: 61.7036 - val_mean_absolute_error: 7.8401
# Epoch 52/80
# 800/800 [==============================] - 0s 33us/step - loss: 8.7002 - mean_absolute_error: 2.4591 - val_loss: 32.6152 - val_mean_absolute_error: 5.7002
# Epoch 53/80
# 800/800 [==============================] - 0s 38us/step - loss: 9.5697 - mean_absolute_error: 2.5644 - val_loss: 11.1331 - val_mean_absolute_error: 3.3306
# Epoch 54/80
# 800/800 [==============================] - 0s 37us/step - loss: 8.6063 - mean_absolute_error: 2.3803 - val_loss: 87.9364 - val_mean_absolute_error: 9.3592
# Epoch 55/80
# 800/800 [==============================] - 0s 46us/step - loss: 7.4579 - mean_absolute_error: 2.1630 - val_loss: 14.9021 - val_mean_absolute_error: 3.8532
# Epoch 56/80
# 800/800 [==============================] - 0s 38us/step - loss: 10.8679 - mean_absolute_error: 2.7750 - val_loss: 7.0945 - val_mean_absolute_error: 2.6589
# Epoch 57/80
# 800/800 [==============================] - 0s 34us/step - loss: 6.5790 - mean_absolute_error: 2.0403 - val_loss: 36.2869 - val_mean_absolute_error: 6.0124
# Epoch 58/80
# 800/800 [==============================] - 0s 35us/step - loss: 9.8604 - mean_absolute_error: 2.7103 - val_loss: 22.5830 - val_mean_absolute_error: 4.7433
# Epoch 59/80
# 800/800 [==============================] - 0s 38us/step - loss: 6.2895 - mean_absolute_error: 2.1786 - val_loss: 30.9824 - val_mean_absolute_error: 5.5556
# Epoch 60/80
# 800/800 [==============================] - 0s 39us/step - loss: 9.7634 - mean_absolute_error: 2.7093 - val_loss: 62.9474 - val_mean_absolute_error: 7.9186
# Epoch 61/80
# 800/800 [==============================] - 0s 32us/step - loss: 8.0002 - mean_absolute_error: 2.2613 - val_loss: 6.0561 - val_mean_absolute_error: 2.4566
# Epoch 62/80
# 800/800 [==============================] - 0s 33us/step - loss: 9.1723 - mean_absolute_error: 2.5123 - val_loss: 45.8281 - val_mean_absolute_error: 6.7566
# Epoch 63/80
# 800/800 [==============================] - 0s 34us/step - loss: 7.2235 - mean_absolute_error: 2.3020 - val_loss: 29.1982 - val_mean_absolute_error: 5.3933
# Epoch 64/80
# 800/800 [==============================] - 0s 33us/step - loss: 10.7757 - mean_absolute_error: 2.8080 - val_loss: 16.0697 - val_mean_absolute_error: 4.0013
# Epoch 65/80
# 800/800 [==============================] - 0s 34us/step - loss: 5.5198 - mean_absolute_error: 1.9518 - val_loss: 56.9708 - val_mean_absolute_error: 7.5333
# Epoch 66/80
# 800/800 [==============================] - 0s 35us/step - loss: 10.2982 - mean_absolute_error: 2.7033 - val_loss: 8.3706 - val_mean_absolute_error: 2.8880
# Epoch 67/80
# 800/800 [==============================] - 0s 34us/step - loss: 7.4543 - mean_absolute_error: 2.3014 - val_loss: 42.3608 - val_mean_absolute_error: 6.4960
# Epoch 68/80
# 800/800 [==============================] - 0s 33us/step - loss: 9.5338 - mean_absolute_error: 2.4851 - val_loss: 1.5175 - val_mean_absolute_error: 1.2300
# Epoch 69/80
# 800/800 [==============================] - 0s 32us/step - loss: 6.4489 - mean_absolute_error: 1.9159 - val_loss: 55.5974 - val_mean_absolute_error: 7.4419
# Epoch 70/80
# 800/800 [==============================] - 0s 36us/step - loss: 10.7559 - mean_absolute_error: 2.8200 - val_loss: 10.8457 - val_mean_absolute_error: 3.2872
# Epoch 71/80
# 800/800 [==============================] - 0s 37us/step - loss: 7.3021 - mean_absolute_error: 2.1475 - val_loss: 40.0186 - val_mean_absolute_error: 6.3138
# Epoch 72/80
# 800/800 [==============================] - 0s 42us/step - loss: 8.7356 - mean_absolute_error: 2.5507 - val_loss: 13.0216 - val_mean_absolute_error: 3.6019
# Epoch 73/80
# 800/800 [==============================] - 0s 32us/step - loss: 7.2108 - mean_absolute_error: 2.2897 - val_loss: 53.5153 - val_mean_absolute_error: 7.3012
# Epoch 74/80
# 800/800 [==============================] - 0s 34us/step - loss: 9.3327 - mean_absolute_error: 2.6352 - val_loss: 30.9559 - val_mean_absolute_error: 5.5531
# Epoch 75/80
# 800/800 [==============================] - 0s 34us/step - loss: 8.7413 - mean_absolute_error: 2.5399 - val_loss: 12.0289 - val_mean_absolute_error: 3.4618
# Epoch 76/80
# 800/800 [==============================] - 0s 34us/step - loss: 7.0111 - mean_absolute_error: 2.2390 - val_loss: 60.7137 - val_mean_absolute_error: 7.7767
# Epoch 77/80
# 800/800 [==============================] - 0s 32us/step - loss: 9.9588 - mean_absolute_error: 2.6708 - val_loss: 40.5701 - val_mean_absolute_error: 6.3571
# Epoch 78/80
# 800/800 [==============================] - 0s 37us/step - loss: 6.8894 - mean_absolute_error: 2.2366 - val_loss: 47.4659 - val_mean_absolute_error: 6.8762
# Epoch 79/80
# 800/800 [==============================] - 0s 36us/step - loss: 8.1480 - mean_absolute_error: 2.3643 - val_loss: 18.9694 - val_mean_absolute_error: 4.3471
# Epoch 80/80
# 800/800 [==============================] - 0s 36us/step - loss: 8.8872 - mean_absolute_error: 2.5629 - val_loss: 29.6574 - val_mean_absolute_error: 5.4354

# %%
plot_metric(h, 'loss')

# %%
plot_metric(h, 'mean_absolute_error')

# %%
m.evaluate(x_test, y_test)
# Out:
# 100/100 [==============================] - 0s 121us/step
# [39.838577880859376, 6.3094873046875]

# %%
y_hat = m.predict(x_test)
plt.plot(x_train, y_train, 'r')
plt.plot(x_test, y_test, 'b')
plt.plot(x_test, y_hat, '--g')
plt.show()

# %%
def build(act=None):
  m = models.Sequential()
  m.add(layers.Dense(units=64, input_shape=(1,), activation=act))
  m.add(layers.Dense(units=16, activation=act))
  m.add(layers.Dense(units=8, activation=act))
  m.add(layers.Dense(units=1, activation=act))
  m.summary()
  m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
  return m

# %%
m = build(act='elu')
h = m.fit(x_train, y_train, batch_size=100, epochs=150, validation_split=0.2)
plot_metric(h, 'loss')
y_hat = m.predict(x_test)
plt.plot(x_train, y_train, 'r')
plt.plot(x_test, y_test, 'b')
plt.plot(x_test, y_hat, '--g')
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_31 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_32 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# Train on 800 samples, validate on 200 samples
# Epoch 1/150
# 800/800 [==============================] - 0s 403us/step - loss: 19036.8645 - mean_absolute_error: 119.7428 - val_loss: 67754.7812 - val_mean_absolute_error: 259.7576
# Epoch 2/150
# 800/800 [==============================] - 0s 34us/step - loss: 16817.4017 - mean_absolute_error: 112.1711 - val_loss: 60781.9824 - val_mean_absolute_error: 246.0226
# Epoch 3/150
# 800/800 [==============================] - 0s 34us/step - loss: 14756.0671 - mean_absolute_error: 104.7683 - val_loss: 52898.8750 - val_mean_absolute_error: 229.5111
# Epoch 4/150
# 800/800 [==============================] - 0s 35us/step - loss: 12839.8196 - mean_absolute_error: 97.4787 - val_loss: 46615.5312 - val_mean_absolute_error: 215.4451
# Epoch 5/150
# 800/800 [==============================] - 0s 33us/step - loss: 11192.0522 - mean_absolute_error: 90.6730 - val_loss: 40505.0117 - val_mean_absolute_error: 200.8230
# Epoch 6/150
# 800/800 [==============================] - 0s 31us/step - loss: 9504.3616 - mean_absolute_error: 83.2911 - val_loss: 34044.4697 - val_mean_absolute_error: 184.1057
# Epoch 7/150
# 800/800 [==============================] - 0s 33us/step - loss: 7758.6872 - mean_absolute_error: 74.8944 - val_loss: 27462.8604 - val_mean_absolute_error: 165.3472
# Epoch 8/150
# 800/800 [==============================] - 0s 32us/step - loss: 6046.9044 - mean_absolute_error: 65.8291 - val_loss: 21155.3291 - val_mean_absolute_error: 145.1151
# Epoch 9/150
# 800/800 [==============================] - 0s 31us/step - loss: 4501.9808 - mean_absolute_error: 56.2537 - val_loss: 15558.3076 - val_mean_absolute_error: 124.4370
# Epoch 10/150
# 800/800 [==============================] - 0s 33us/step - loss: 3116.0663 - mean_absolute_error: 46.2996 - val_loss: 10544.8867 - val_mean_absolute_error: 102.4321
# Epoch 11/150
# 800/800 [==============================] - 0s 32us/step - loss: 1938.4418 - mean_absolute_error: 36.0173 - val_loss: 6361.8840 - val_mean_absolute_error: 79.5461
# Epoch 12/150
# 800/800 [==============================] - 0s 31us/step - loss: 1029.3362 - mean_absolute_error: 25.8219 - val_loss: 3256.6394 - val_mean_absolute_error: 56.8913
# Epoch 13/150
# 800/800 [==============================] - 0s 34us/step - loss: 438.1520 - mean_absolute_error: 16.5047 - val_loss: 1349.6952 - val_mean_absolute_error: 36.5958
# Epoch 14/150
# 800/800 [==============================] - 0s 33us/step - loss: 142.9263 - mean_absolute_error: 9.4962 - val_loss: 460.6862 - val_mean_absolute_error: 21.3408
# Epoch 15/150
# 800/800 [==============================] - 0s 30us/step - loss: 44.7086 - mean_absolute_error: 5.7179 - val_loss: 172.6399 - val_mean_absolute_error: 13.0264
# Epoch 16/150
# 800/800 [==============================] - 0s 31us/step - loss: 19.3976 - mean_absolute_error: 3.8674 - val_loss: 67.9441 - val_mean_absolute_error: 8.1305
# Epoch 17/150
# 800/800 [==============================] - 0s 32us/step - loss: 11.7441 - mean_absolute_error: 3.0326 - val_loss: 17.8709 - val_mean_absolute_error: 4.0789
# Epoch 18/150
# 800/800 [==============================] - 0s 33us/step - loss: 8.7923 - mean_absolute_error: 2.5779 - val_loss: 42.1011 - val_mean_absolute_error: 6.4077
# Epoch 19/150
# 800/800 [==============================] - 0s 32us/step - loss: 5.6810 - mean_absolute_error: 2.0874 - val_loss: 39.2890 - val_mean_absolute_error: 6.2023
# Epoch 20/150
# 800/800 [==============================] - 0s 33us/step - loss: 4.6132 - mean_absolute_error: 1.8350 - val_loss: 37.1568 - val_mean_absolute_error: 6.0371
# Epoch 21/150
# 800/800 [==============================] - 0s 35us/step - loss: 5.2573 - mean_absolute_error: 1.9514 - val_loss: 38.3016 - val_mean_absolute_error: 6.1206
# Epoch 22/150
# 800/800 [==============================] - 0s 33us/step - loss: 4.6754 - mean_absolute_error: 1.7065 - val_loss: 54.0849 - val_mean_absolute_error: 7.2818
# Epoch 23/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.4524 - mean_absolute_error: 0.9019 - val_loss: 8.2684 - val_mean_absolute_error: 2.7928
# Epoch 24/150
# 800/800 [==============================] - 0s 34us/step - loss: 6.5793 - mean_absolute_error: 1.7506 - val_loss: 14.8190 - val_mean_absolute_error: 3.7504
# Epoch 25/150
# 800/800 [==============================] - 0s 38us/step - loss: 0.6496 - mean_absolute_error: 0.6589 - val_loss: 16.9484 - val_mean_absolute_error: 4.0549
# Epoch 26/150
# 800/800 [==============================] - 0s 35us/step - loss: 4.0361 - mean_absolute_error: 1.6531 - val_loss: 22.8363 - val_mean_absolute_error: 4.7087
# Epoch 27/150
# 800/800 [==============================] - 0s 36us/step - loss: 3.9826 - mean_absolute_error: 1.6771 - val_loss: 27.9799 - val_mean_absolute_error: 5.2126
# Epoch 28/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.0196 - mean_absolute_error: 1.1859 - val_loss: 21.9720 - val_mean_absolute_error: 4.6163
# Epoch 29/150
# 800/800 [==============================] - 0s 33us/step - loss: 3.7468 - mean_absolute_error: 1.6161 - val_loss: 28.9594 - val_mean_absolute_error: 5.3010
# Epoch 30/150
# 800/800 [==============================] - 0s 33us/step - loss: 1.9823 - mean_absolute_error: 1.1313 - val_loss: 32.1405 - val_mean_absolute_error: 5.6046
# Epoch 31/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.8392 - mean_absolute_error: 1.3780 - val_loss: 20.9490 - val_mean_absolute_error: 4.5009
# Epoch 32/150
# 800/800 [==============================] - 0s 31us/step - loss: 3.8577 - mean_absolute_error: 1.6043 - val_loss: 21.6437 - val_mean_absolute_error: 4.5656
# Epoch 33/150
# 800/800 [==============================] - 0s 31us/step - loss: 1.4212 - mean_absolute_error: 0.9358 - val_loss: 34.6758 - val_mean_absolute_error: 5.8282
# Epoch 34/150
# 800/800 [==============================] - 0s 32us/step - loss: 3.5873 - mean_absolute_error: 1.4568 - val_loss: 17.1129 - val_mean_absolute_error: 4.0591
# Epoch 35/150
# 800/800 [==============================] - 0s 41us/step - loss: 2.5862 - mean_absolute_error: 1.3250 - val_loss: 19.5345 - val_mean_absolute_error: 4.3408
# Epoch 36/150
# 800/800 [==============================] - 0s 35us/step - loss: 3.2110 - mean_absolute_error: 1.4606 - val_loss: 22.1050 - val_mean_absolute_error: 4.6187
# Epoch 37/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.6716 - mean_absolute_error: 0.9565 - val_loss: 47.5386 - val_mean_absolute_error: 6.8315
# Epoch 38/150
# 800/800 [==============================] - 0s 38us/step - loss: 3.1817 - mean_absolute_error: 1.3581 - val_loss: 15.7137 - val_mean_absolute_error: 3.8851
# Epoch 39/150
# 800/800 [==============================] - 0s 37us/step - loss: 3.3414 - mean_absolute_error: 1.5422 - val_loss: 29.6105 - val_mean_absolute_error: 5.3700
# Epoch 40/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.8100 - mean_absolute_error: 1.0664 - val_loss: 16.6701 - val_mean_absolute_error: 4.0099
# Epoch 41/150
# 800/800 [==============================] - 0s 33us/step - loss: 3.2568 - mean_absolute_error: 1.4721 - val_loss: 20.3192 - val_mean_absolute_error: 4.4316
# Epoch 42/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.6640 - mean_absolute_error: 1.3278 - val_loss: 34.4781 - val_mean_absolute_error: 5.8033
# Epoch 43/150
# 800/800 [==============================] - 0s 32us/step - loss: 1.6646 - mean_absolute_error: 1.0157 - val_loss: 23.3040 - val_mean_absolute_error: 4.7621
# Epoch 44/150
# 800/800 [==============================] - 0s 34us/step - loss: 3.0603 - mean_absolute_error: 1.4235 - val_loss: 12.9676 - val_mean_absolute_error: 3.5188
# Epoch 45/150
# 800/800 [==============================] - 0s 32us/step - loss: 3.3582 - mean_absolute_error: 1.4604 - val_loss: 26.9038 - val_mean_absolute_error: 5.1140
# Epoch 46/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.0893 - mean_absolute_error: 0.8122 - val_loss: 26.3126 - val_mean_absolute_error: 5.0728
# Epoch 47/150
# 800/800 [==============================] - 0s 33us/step - loss: 3.5423 - mean_absolute_error: 1.5820 - val_loss: 15.3293 - val_mean_absolute_error: 3.8416
# Epoch 48/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.4213 - mean_absolute_error: 1.2547 - val_loss: 30.5629 - val_mean_absolute_error: 5.4613
# Epoch 49/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.9295 - mean_absolute_error: 1.1543 - val_loss: 18.1646 - val_mean_absolute_error: 4.1923
# Epoch 50/150
# 800/800 [==============================] - 0s 37us/step - loss: 2.6351 - mean_absolute_error: 1.3776 - val_loss: 26.2974 - val_mean_absolute_error: 5.0650
# Epoch 51/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.3773 - mean_absolute_error: 1.2855 - val_loss: 14.4912 - val_mean_absolute_error: 3.7359
# Epoch 52/150
# 800/800 [==============================] - 0s 33us/step - loss: 3.1955 - mean_absolute_error: 1.4284 - val_loss: 35.8121 - val_mean_absolute_error: 5.9195
# Epoch 53/150
# 800/800 [==============================] - 0s 38us/step - loss: 0.9117 - mean_absolute_error: 0.6743 - val_loss: 7.4593 - val_mean_absolute_error: 2.6542
# Epoch 54/150
# 800/800 [==============================] - 0s 36us/step - loss: 4.3406 - mean_absolute_error: 1.5491 - val_loss: 23.4849 - val_mean_absolute_error: 4.7771
# Epoch 55/150
# 800/800 [==============================] - 0s 34us/step - loss: 0.3685 - mean_absolute_error: 0.4499 - val_loss: 4.6305 - val_mean_absolute_error: 2.0656
# Epoch 56/150
# 800/800 [==============================] - 0s 37us/step - loss: 2.6676 - mean_absolute_error: 1.1571 - val_loss: 39.2476 - val_mean_absolute_error: 6.2050
# Epoch 57/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.6751 - mean_absolute_error: 1.0012 - val_loss: 24.0332 - val_mean_absolute_error: 4.8486
# Epoch 58/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.7129 - mean_absolute_error: 1.3831 - val_loss: 15.7811 - val_mean_absolute_error: 3.9094
# Epoch 59/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.6897 - mean_absolute_error: 1.3355 - val_loss: 32.2987 - val_mean_absolute_error: 5.6240
# Epoch 60/150
# 800/800 [==============================] - 0s 36us/step - loss: 0.8824 - mean_absolute_error: 0.7097 - val_loss: 16.0529 - val_mean_absolute_error: 3.9486
# Epoch 61/150
# 800/800 [==============================] - 0s 32us/step - loss: 3.1552 - mean_absolute_error: 1.4783 - val_loss: 15.3134 - val_mean_absolute_error: 3.8494
# Epoch 62/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.6385 - mean_absolute_error: 1.0928 - val_loss: 20.5093 - val_mean_absolute_error: 4.4720
# Epoch 63/150
# 800/800 [==============================] - 0s 37us/step - loss: 2.4637 - mean_absolute_error: 1.3549 - val_loss: 19.8008 - val_mean_absolute_error: 4.3894
# Epoch 64/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.9590 - mean_absolute_error: 1.1697 - val_loss: 19.7884 - val_mean_absolute_error: 4.3922
# Epoch 65/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.4293 - mean_absolute_error: 1.3086 - val_loss: 13.1017 - val_mean_absolute_error: 3.5563
# Epoch 66/150
# 800/800 [==============================] - 0s 40us/step - loss: 2.5712 - mean_absolute_error: 1.3086 - val_loss: 18.3272 - val_mean_absolute_error: 4.2215
# Epoch 67/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.7697 - mean_absolute_error: 1.0464 - val_loss: 25.9396 - val_mean_absolute_error: 5.0401
# Epoch 68/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.0230 - mean_absolute_error: 1.2199 - val_loss: 23.2118 - val_mean_absolute_error: 4.7653
# Epoch 69/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.2006 - mean_absolute_error: 1.2819 - val_loss: 22.9887 - val_mean_absolute_error: 4.7407
# Epoch 70/150
# 800/800 [==============================] - 0s 43us/step - loss: 2.2697 - mean_absolute_error: 1.3028 - val_loss: 14.5513 - val_mean_absolute_error: 3.7558
# Epoch 71/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.7084 - mean_absolute_error: 1.0991 - val_loss: 30.7886 - val_mean_absolute_error: 5.4987
# Epoch 72/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.1054 - mean_absolute_error: 1.1361 - val_loss: 11.6343 - val_mean_absolute_error: 3.3549
# Epoch 73/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.5420 - mean_absolute_error: 1.3395 - val_loss: 22.2495 - val_mean_absolute_error: 4.6629
# Epoch 74/150
# 800/800 [==============================] - 0s 37us/step - loss: 1.3120 - mean_absolute_error: 0.9646 - val_loss: 21.1301 - val_mean_absolute_error: 4.5465
# Epoch 75/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.7387 - mean_absolute_error: 1.4389 - val_loss: 12.8764 - val_mean_absolute_error: 3.5320
# Epoch 76/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.4847 - mean_absolute_error: 1.0244 - val_loss: 26.5359 - val_mean_absolute_error: 5.1011
# Epoch 77/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.2533 - mean_absolute_error: 1.2688 - val_loss: 14.2714 - val_mean_absolute_error: 3.7246
# Epoch 78/150
# 800/800 [==============================] - 0s 38us/step - loss: 2.1736 - mean_absolute_error: 1.2320 - val_loss: 29.9828 - val_mean_absolute_error: 5.4243
# Epoch 79/150
# 800/800 [==============================] - 0s 29us/step - loss: 1.5724 - mean_absolute_error: 0.9391 - val_loss: 11.3458 - val_mean_absolute_error: 3.3166
# Epoch 80/150
# 800/800 [==============================] - 0s 31us/step - loss: 2.8200 - mean_absolute_error: 1.4545 - val_loss: 19.4818 - val_mean_absolute_error: 4.3610
# Epoch 81/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.1879 - mean_absolute_error: 0.8803 - val_loss: 10.5149 - val_mean_absolute_error: 3.1923
# Epoch 82/150
# 800/800 [==============================] - 0s 36us/step - loss: 3.0622 - mean_absolute_error: 1.4594 - val_loss: 19.2589 - val_mean_absolute_error: 4.3361
# Epoch 83/150
# 800/800 [==============================] - 0s 31us/step - loss: 0.8336 - mean_absolute_error: 0.7329 - val_loss: 12.0661 - val_mean_absolute_error: 3.4243
# Epoch 84/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.6692 - mean_absolute_error: 1.3667 - val_loss: 11.0184 - val_mean_absolute_error: 3.2639
# Epoch 85/150
# 800/800 [==============================] - 0s 38us/step - loss: 1.6555 - mean_absolute_error: 1.0530 - val_loss: 24.6738 - val_mean_absolute_error: 4.9203
# Epoch 86/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.6768 - mean_absolute_error: 1.0977 - val_loss: 23.0851 - val_mean_absolute_error: 4.7595
# Epoch 87/150
# 800/800 [==============================] - 0s 37us/step - loss: 2.4610 - mean_absolute_error: 1.3553 - val_loss: 21.0125 - val_mean_absolute_error: 4.5355
# Epoch 88/150
# 800/800 [==============================] - 0s 32us/step - loss: 1.1593 - mean_absolute_error: 0.8190 - val_loss: 10.3593 - val_mean_absolute_error: 3.1701
# Epoch 89/150
# 800/800 [==============================] - 0s 37us/step - loss: 3.0062 - mean_absolute_error: 1.4100 - val_loss: 8.9662 - val_mean_absolute_error: 2.9382
# Epoch 90/150
# 800/800 [==============================] - 0s 36us/step - loss: 0.6974 - mean_absolute_error: 0.6552 - val_loss: 18.2789 - val_mean_absolute_error: 4.2317
# Epoch 91/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.6945 - mean_absolute_error: 1.4351 - val_loss: 18.0824 - val_mean_absolute_error: 4.2047
# Epoch 92/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.2785 - mean_absolute_error: 0.9633 - val_loss: 19.8653 - val_mean_absolute_error: 4.4129
# Epoch 93/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.0719 - mean_absolute_error: 1.2027 - val_loss: 12.7080 - val_mean_absolute_error: 3.5155
# Epoch 94/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.1598 - mean_absolute_error: 1.2693 - val_loss: 26.6613 - val_mean_absolute_error: 5.1168
# Epoch 95/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.3533 - mean_absolute_error: 0.9661 - val_loss: 16.3368 - val_mean_absolute_error: 3.9955
# Epoch 96/150
# 800/800 [==============================] - 0s 39us/step - loss: 2.6243 - mean_absolute_error: 1.4084 - val_loss: 18.6034 - val_mean_absolute_error: 4.2689
# Epoch 97/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.1180 - mean_absolute_error: 0.8788 - val_loss: 14.5208 - val_mean_absolute_error: 3.7667
# Epoch 98/150
# 800/800 [==============================] - 0s 31us/step - loss: 2.7761 - mean_absolute_error: 1.4450 - val_loss: 13.6892 - val_mean_absolute_error: 3.6512
# Epoch 99/150
# 800/800 [==============================] - 0s 33us/step - loss: 1.0151 - mean_absolute_error: 0.8420 - val_loss: 14.9484 - val_mean_absolute_error: 3.8219
# Epoch 100/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.3618 - mean_absolute_error: 1.2876 - val_loss: 9.2249 - val_mean_absolute_error: 2.9885
# Epoch 101/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.0508 - mean_absolute_error: 0.7396 - val_loss: 45.8026 - val_mean_absolute_error: 6.7276
# Epoch 102/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.3919 - mean_absolute_error: 1.0871 - val_loss: 6.9941 - val_mean_absolute_error: 2.5945
# Epoch 103/150
# 800/800 [==============================] - 0s 36us/step - loss: 2.0594 - mean_absolute_error: 1.1436 - val_loss: 24.6499 - val_mean_absolute_error: 4.9212
# Epoch 104/150
# 800/800 [==============================] - 0s 40us/step - loss: 1.0126 - mean_absolute_error: 0.7886 - val_loss: 12.8421 - val_mean_absolute_error: 3.5401
# Epoch 105/150
# 800/800 [==============================] - 0s 41us/step - loss: 2.4629 - mean_absolute_error: 1.3597 - val_loss: 12.9805 - val_mean_absolute_error: 3.5554
# Epoch 106/150
# 800/800 [==============================] - 0s 39us/step - loss: 1.5390 - mean_absolute_error: 0.9580 - val_loss: 27.1068 - val_mean_absolute_error: 5.1646
# Epoch 107/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.5886 - mean_absolute_error: 0.9864 - val_loss: 10.9775 - val_mean_absolute_error: 3.2693
# Epoch 108/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.3081 - mean_absolute_error: 1.3181 - val_loss: 18.0377 - val_mean_absolute_error: 4.2049
# Epoch 109/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.5607 - mean_absolute_error: 1.0738 - val_loss: 16.5975 - val_mean_absolute_error: 4.0336
# Epoch 110/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.6576 - mean_absolute_error: 1.1061 - val_loss: 13.9438 - val_mean_absolute_error: 3.6912
# Epoch 111/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.2791 - mean_absolute_error: 1.3026 - val_loss: 9.5902 - val_mean_absolute_error: 3.0493
# Epoch 112/150
# 800/800 [==============================] - 0s 32us/step - loss: 1.3779 - mean_absolute_error: 0.9872 - val_loss: 20.7767 - val_mean_absolute_error: 4.5173
# Epoch 113/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.9262 - mean_absolute_error: 1.1327 - val_loss: 6.6580 - val_mean_absolute_error: 2.5321
# Epoch 114/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.2280 - mean_absolute_error: 1.1626 - val_loss: 28.5122 - val_mean_absolute_error: 5.2976
# Epoch 115/150
# 800/800 [==============================] - 0s 31us/step - loss: 0.9005 - mean_absolute_error: 0.7382 - val_loss: 11.7193 - val_mean_absolute_error: 3.3816
# Epoch 116/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.5306 - mean_absolute_error: 1.3615 - val_loss: 12.9791 - val_mean_absolute_error: 3.5585
# Epoch 117/150
# 800/800 [==============================] - 0s 33us/step - loss: 0.8730 - mean_absolute_error: 0.7248 - val_loss: 27.6168 - val_mean_absolute_error: 5.2180
# Epoch 118/150
# 800/800 [==============================] - 0s 37us/step - loss: 2.1127 - mean_absolute_error: 1.2157 - val_loss: 15.0290 - val_mean_absolute_error: 3.8354
# Epoch 119/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.8914 - mean_absolute_error: 1.1994 - val_loss: 16.9067 - val_mean_absolute_error: 4.0707
# Epoch 120/150
# 800/800 [==============================] - 0s 34us/step - loss: 1.6617 - mean_absolute_error: 1.0748 - val_loss: 24.4730 - val_mean_absolute_error: 4.9069
# Epoch 121/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.5412 - mean_absolute_error: 1.0059 - val_loss: 9.8962 - val_mean_absolute_error: 3.1035
# Epoch 122/150
# 800/800 [==============================] - 0s 33us/step - loss: 1.9769 - mean_absolute_error: 1.2052 - val_loss: 23.7820 - val_mean_absolute_error: 4.8360
# Epoch 123/150
# 800/800 [==============================] - 0s 32us/step - loss: 1.1125 - mean_absolute_error: 0.8362 - val_loss: 15.8281 - val_mean_absolute_error: 3.9397
# Epoch 124/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.3814 - mean_absolute_error: 1.3152 - val_loss: 11.5039 - val_mean_absolute_error: 3.3510
# Epoch 125/150
# 800/800 [==============================] - 0s 42us/step - loss: 1.3785 - mean_absolute_error: 1.0191 - val_loss: 11.6683 - val_mean_absolute_error: 3.3754
# Epoch 126/150
# 800/800 [==============================] - 0s 33us/step - loss: 2.2654 - mean_absolute_error: 1.2856 - val_loss: 9.3176 - val_mean_absolute_error: 3.0083
# Epoch 127/150
# 800/800 [==============================] - 0s 38us/step - loss: 1.2764 - mean_absolute_error: 0.8872 - val_loss: 30.4479 - val_mean_absolute_error: 5.4811
# Epoch 128/150
# 800/800 [==============================] - 0s 33us/step - loss: 1.9248 - mean_absolute_error: 1.0893 - val_loss: 6.4328 - val_mean_absolute_error: 2.4933
# Epoch 129/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.0103 - mean_absolute_error: 1.1620 - val_loss: 13.3755 - val_mean_absolute_error: 3.6164
# Epoch 130/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.2128 - mean_absolute_error: 0.9475 - val_loss: 12.3019 - val_mean_absolute_error: 3.4683
# Epoch 131/150
# 800/800 [==============================] - 0s 35us/step - loss: 2.2310 - mean_absolute_error: 1.2732 - val_loss: 15.3565 - val_mean_absolute_error: 3.8786
# Epoch 132/150
# 800/800 [==============================] - 0s 37us/step - loss: 1.2613 - mean_absolute_error: 0.9588 - val_loss: 7.3885 - val_mean_absolute_error: 2.6753
# Epoch 133/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.1914 - mean_absolute_error: 1.2150 - val_loss: 10.6675 - val_mean_absolute_error: 3.2261
# Epoch 134/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.0575 - mean_absolute_error: 0.8844 - val_loss: 17.0392 - val_mean_absolute_error: 4.0916
# Epoch 135/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.0469 - mean_absolute_error: 1.2081 - val_loss: 12.1423 - val_mean_absolute_error: 3.4483
# Epoch 136/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.6557 - mean_absolute_error: 1.0874 - val_loss: 8.2887 - val_mean_absolute_error: 2.8397
# Epoch 137/150
# 800/800 [==============================] - 0s 36us/step - loss: 1.9441 - mean_absolute_error: 1.1492 - val_loss: 26.7898 - val_mean_absolute_error: 5.1384
# Epoch 138/150
# 800/800 [==============================] - 0s 39us/step - loss: 1.1478 - mean_absolute_error: 0.8560 - val_loss: 12.9612 - val_mean_absolute_error: 3.5647
# Epoch 139/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.1252 - mean_absolute_error: 1.2624 - val_loss: 10.8564 - val_mean_absolute_error: 3.2584
# Epoch 140/150
# 800/800 [==============================] - 0s 31us/step - loss: 1.4700 - mean_absolute_error: 1.0640 - val_loss: 16.1418 - val_mean_absolute_error: 3.9806
# Epoch 141/150
# 800/800 [==============================] - 0s 48us/step - loss: 1.9778 - mean_absolute_error: 1.1987 - val_loss: 19.4325 - val_mean_absolute_error: 4.3728
# Epoch 142/150
# 800/800 [==============================] - 0s 37us/step - loss: 1.2925 - mean_absolute_error: 0.8790 - val_loss: 5.2180 - val_mean_absolute_error: 2.2436
# Epoch 143/150
# 800/800 [==============================] - 0s 29us/step - loss: 2.4130 - mean_absolute_error: 1.2453 - val_loss: 14.2779 - val_mean_absolute_error: 3.7413
# Epoch 144/150
# 800/800 [==============================] - 0s 32us/step - loss: 0.6747 - mean_absolute_error: 0.5971 - val_loss: 3.2411 - val_mean_absolute_error: 1.7560
# Epoch 145/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.7565 - mean_absolute_error: 1.2725 - val_loss: 10.3768 - val_mean_absolute_error: 3.1831
# Epoch 146/150
# 800/800 [==============================] - 0s 37us/step - loss: 0.2937 - mean_absolute_error: 0.4097 - val_loss: 6.5641 - val_mean_absolute_error: 2.5250
# Epoch 147/150
# 800/800 [==============================] - 0s 32us/step - loss: 2.7861 - mean_absolute_error: 1.4090 - val_loss: 8.3923 - val_mean_absolute_error: 2.8583
# Epoch 148/150
# 800/800 [==============================] - 0s 32us/step - loss: 0.4042 - mean_absolute_error: 0.5020 - val_loss: 17.0258 - val_mean_absolute_error: 4.0938
# Epoch 149/150
# 800/800 [==============================] - 0s 34us/step - loss: 2.2656 - mean_absolute_error: 1.0993 - val_loss: 3.6261 - val_mean_absolute_error: 1.8603
# Epoch 150/150
# 800/800 [==============================] - 0s 35us/step - loss: 1.2677 - mean_absolute_error: 0.7352 - val_loss: 42.1713 - val_mean_absolute_error: 6.4592

# %% [markdown]
# ### Now another more complex function
#
# Let's try to fit a parabollic function
#
# $\displaystyle y = -2x^2 + x + 1$

# %%
x_train = np.linspace(-100, 100, 10000)
y_train = -2*x_train**2 + x_train + 1

xt_min = x_train.min()
xt_max = x_train.max()
yt_min = y_train.min()
yt_max = y_train.max()

x_train_scaled = (x_train - xt_min) / (xt_max - xt_min)
y_train_scaled = (y_train - yt_min) / (yt_max - yt_min)

x_test = np.linspace(100.01, 110, 100)
y_test = -2*x_test**2 + x_test + 1

x_test_scaled = (x_test - xt_min) / (xt_max - xt_min)
y_test_scaled = (y_test - yt_min) / (yt_max - yt_min)

plt.plot(x_train, y_train, 'b')
plt.plot(x_test, y_test, 'r')
plt.show()

plt.plot(x_train_scaled, y_train_scaled, 'b')
plt.plot(x_test_scaled, y_test_scaled, 'r')
plt.show()

# %%
def build(act=None):
  m = models.Sequential()
  m.add(layers.Dense(units=64, input_shape=(1,), activation=act))
  m.add(layers.Dense(units=16, activation=act))
  m.add(layers.Dense(units=8, activation=act))
  m.add(layers.Dense(units=1, activation=act))
  m.summary()
  m.compile(optimizer=optimizers.rmsprop(), loss=losses.mean_squared_error, metrics=[metrics.mae])
  return m

# %%
m = build(act='elu')
h = m.fit(x_train_scaled, y_train_scaled, batch_size=100, epochs=150, validation_split=0.2)
plot_metric(h, 'loss')
y_hat = m.predict(x_test_scaled)
plt.plot(x_train_scaled, y_train_scaled, 'r')
plt.plot(x_test_scaled, y_test_scaled, 'b')
plt.plot(x_test_scaled, y_hat, '--g')
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_38 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_39 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_40 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/150
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.0652 - mean_absolute_error: 0.1982 - val_loss: 0.7170 - val_mean_absolute_error: 0.8164
# Epoch 2/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 0.0323 - mean_absolute_error: 0.1537 - val_loss: 0.4551 - val_mean_absolute_error: 0.6411
# Epoch 3/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 0.0265 - mean_absolute_error: 0.1388 - val_loss: 0.4338 - val_mean_absolute_error: 0.6300
# Epoch 4/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 0.0133 - mean_absolute_error: 0.0947 - val_loss: 0.2872 - val_mean_absolute_error: 0.5119
# Epoch 5/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 0.0034 - mean_absolute_error: 0.0426 - val_loss: 0.1202 - val_mean_absolute_error: 0.3210
# Epoch 6/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 0.0018 - mean_absolute_error: 0.0326 - val_loss: 0.1122 - val_mean_absolute_error: 0.3120
# Epoch 7/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 0.0015 - mean_absolute_error: 0.0310 - val_loss: 0.0975 - val_mean_absolute_error: 0.2893
# Epoch 8/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 0.0015 - mean_absolute_error: 0.0313 - val_loss: 0.0939 - val_mean_absolute_error: 0.2844
# Epoch 9/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 0.0014 - mean_absolute_error: 0.0300 - val_loss: 0.0456 - val_mean_absolute_error: 0.1813
# Epoch 10/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 0.0014 - mean_absolute_error: 0.0300 - val_loss: 0.0538 - val_mean_absolute_error: 0.2039
# Epoch 11/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 0.0012 - mean_absolute_error: 0.0283 - val_loss: 0.0484 - val_mean_absolute_error: 0.1911
# Epoch 12/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 0.0541 - val_mean_absolute_error: 0.2062
# Epoch 13/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 0.0011 - mean_absolute_error: 0.0260 - val_loss: 0.0594 - val_mean_absolute_error: 0.2200
# Epoch 14/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 0.0011 - mean_absolute_error: 0.0255 - val_loss: 0.0482 - val_mean_absolute_error: 0.1937
# Epoch 15/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 0.0010 - mean_absolute_error: 0.0256 - val_loss: 0.0354 - val_mean_absolute_error: 0.1582
# Epoch 16/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 9.4291e-04 - mean_absolute_error: 0.0247 - val_loss: 0.0345 - val_mean_absolute_error: 0.1562
# Epoch 17/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 8.7086e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0245 - val_mean_absolute_error: 0.1238
# Epoch 18/150
# 8000/8000 [==============================] - 0s 27us/step - loss: 7.8313e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0279 - val_mean_absolute_error: 0.1357
# Epoch 19/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 8.2457e-04 - mean_absolute_error: 0.0231 - val_loss: 0.0360 - val_mean_absolute_error: 0.1637
# Epoch 20/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 7.6151e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0647 - val_mean_absolute_error: 0.2359
# Epoch 21/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 7.3030e-04 - mean_absolute_error: 0.0228 - val_loss: 0.0683 - val_mean_absolute_error: 0.2440
# Epoch 22/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 6.6259e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0473 - val_mean_absolute_error: 0.1971
# Epoch 23/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 6.0763e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0311 - val_mean_absolute_error: 0.1511
# Epoch 24/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 6.4267e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0463 - val_mean_absolute_error: 0.1955
# Epoch 25/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 6.0308e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0474 - val_mean_absolute_error: 0.1984
# Epoch 26/150
# 8000/8000 [==============================] - 0s 27us/step - loss: 6.1151e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0532 - val_mean_absolute_error: 0.2126
# Epoch 27/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 5.8161e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0364 - val_mean_absolute_error: 0.1694
# Epoch 28/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 5.3381e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0448 - val_mean_absolute_error: 0.1928
# Epoch 29/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 5.3750e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0218 - val_mean_absolute_error: 0.1192
# Epoch 30/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 5.1547e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0402 - val_mean_absolute_error: 0.1808
# Epoch 31/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 5.1245e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0316 - val_mean_absolute_error: 0.1565
# Epoch 32/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 5.0267e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0299 - val_mean_absolute_error: 0.1512
# Epoch 33/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 4.7782e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0470 - val_mean_absolute_error: 0.1997
# Epoch 34/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 4.8147e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0384 - val_mean_absolute_error: 0.1771
# Epoch 35/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 4.5996e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0379 - val_mean_absolute_error: 0.1758
# Epoch 36/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 4.6048e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0179 - val_mean_absolute_error: 0.1052
# Epoch 37/150
# 8000/8000 [==============================] - 0s 37us/step - loss: 4.2708e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0168 - val_mean_absolute_error: 0.1003
# Epoch 38/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 4.5015e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0203 - val_mean_absolute_error: 0.1155
# Epoch 39/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 4.2339e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0152 - val_mean_absolute_error: 0.0945
# Epoch 40/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 4.3719e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0260 - val_mean_absolute_error: 0.1387
# Epoch 41/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 4.1891e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0235 - val_mean_absolute_error: 0.1288
# Epoch 42/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 4.0902e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0290 - val_mean_absolute_error: 0.1494
# Epoch 43/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 4.1525e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0385 - val_mean_absolute_error: 0.1778
# Epoch 44/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 3.9071e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0224 - val_mean_absolute_error: 0.1238
# Epoch 45/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 4.0811e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0168 - val_mean_absolute_error: 0.1006
# Epoch 46/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.8350e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0259 - val_mean_absolute_error: 0.1377
# Epoch 47/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.9746e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0157 - val_mean_absolute_error: 0.0963
# Epoch 48/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 3.7985e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0171 - val_mean_absolute_error: 0.1019
# Epoch 49/150
# 8000/8000 [==============================] - 0s 33us/step - loss: 3.8291e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0148 - val_mean_absolute_error: 0.0931
# Epoch 50/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 3.7099e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0230 - val_mean_absolute_error: 0.1278
# Epoch 51/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.6082e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0170 - val_mean_absolute_error: 0.1015
# Epoch 52/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.9073e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0167 - val_mean_absolute_error: 0.1004
# Epoch 53/150
# 8000/8000 [==============================] - 0s 35us/step - loss: 3.5899e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0214 - val_mean_absolute_error: 0.1203
# Epoch 54/150
# 8000/8000 [==============================] - 0s 33us/step - loss: 3.6575e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0217 - val_mean_absolute_error: 0.1213
# Epoch 55/150
# 8000/8000 [==============================] - 0s 27us/step - loss: 3.3802e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0403 - val_mean_absolute_error: 0.1832
# Epoch 56/150
# 8000/8000 [==============================] - 0s 27us/step - loss: 3.5178e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0209 - val_mean_absolute_error: 0.1185
# Epoch 57/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 3.5402e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0235 - val_mean_absolute_error: 0.1288
# Epoch 58/150
# 8000/8000 [==============================] - 0s 33us/step - loss: 3.4493e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0224 - val_mean_absolute_error: 0.1240
# Epoch 59/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.4929e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0210 - val_mean_absolute_error: 0.1181
# Epoch 60/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 3.4220e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0206 - val_mean_absolute_error: 0.1175
# Epoch 61/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 3.3644e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0392 - val_mean_absolute_error: 0.1805
# Epoch 62/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.2476e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0199 - val_mean_absolute_error: 0.1137
# Epoch 63/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.3632e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0252 - val_mean_absolute_error: 0.1354
# Epoch 64/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 3.2065e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0147 - val_mean_absolute_error: 0.0926
# Epoch 65/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 3.3728e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0353 - val_mean_absolute_error: 0.1688
# Epoch 66/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.3333e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0204 - val_mean_absolute_error: 0.1164
# Epoch 67/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 3.1362e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0343 - val_mean_absolute_error: 0.1656
# Epoch 68/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 3.1343e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0329 - val_mean_absolute_error: 0.1622
# Epoch 69/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 3.1373e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0221 - val_mean_absolute_error: 0.1232
# Epoch 70/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 3.1172e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0171 - val_mean_absolute_error: 0.1024
# Epoch 71/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 3.1101e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0331 - val_mean_absolute_error: 0.1629
# Epoch 72/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 3.1399e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0186 - val_mean_absolute_error: 0.1089
# Epoch 73/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 3.0123e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0235 - val_mean_absolute_error: 0.1290
# Epoch 74/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 3.0817e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0259 - val_mean_absolute_error: 0.1388
# Epoch 75/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 3.0105e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0245 - val_mean_absolute_error: 0.1330
# Epoch 76/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.9212e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0277 - val_mean_absolute_error: 0.1457
# Epoch 77/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.8369e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0229 - val_mean_absolute_error: 0.1268
# Epoch 78/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 3.0325e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0256 - val_mean_absolute_error: 0.1378
# Epoch 79/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.8188e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0203 - val_mean_absolute_error: 0.1160
# Epoch 80/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.9229e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0165 - val_mean_absolute_error: 0.0997
# Epoch 81/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.8719e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0200 - val_mean_absolute_error: 0.1153
# Epoch 82/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.7895e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0263 - val_mean_absolute_error: 0.1401
# Epoch 83/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.7797e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0208 - val_mean_absolute_error: 0.1182
# Epoch 84/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.9654e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0324 - val_mean_absolute_error: 0.1602
# Epoch 85/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.7205e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0237 - val_mean_absolute_error: 0.1300
# Epoch 86/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.9225e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0327 - val_mean_absolute_error: 0.1611
# Epoch 87/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.6740e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0263 - val_mean_absolute_error: 0.1403
# Epoch 88/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.7968e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0235 - val_mean_absolute_error: 0.1301
# Epoch 89/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.6745e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0233 - val_mean_absolute_error: 0.1284
# Epoch 90/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.7143e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0262 - val_mean_absolute_error: 0.1401
# Epoch 91/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.7167e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0308 - val_mean_absolute_error: 0.1552
# Epoch 92/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.6640e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0192 - val_mean_absolute_error: 0.1115
# Epoch 93/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.6877e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0331 - val_mean_absolute_error: 0.1626
# Epoch 94/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.6433e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0241 - val_mean_absolute_error: 0.1315
# Epoch 95/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.6863e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0296 - val_mean_absolute_error: 0.1511
# Epoch 96/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.5344e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0219 - val_mean_absolute_error: 0.1239
# Epoch 97/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.5288e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0149 - val_mean_absolute_error: 0.0935
# Epoch 98/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.6227e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0416 - val_mean_absolute_error: 0.1871
# Epoch 99/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.6215e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0321 - val_mean_absolute_error: 0.1599
# Epoch 100/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.5627e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0191 - val_mean_absolute_error: 0.1127
# Epoch 101/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.3724e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0366 - val_mean_absolute_error: 0.1732
# Epoch 102/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.6513e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0243 - val_mean_absolute_error: 0.1331
# Epoch 103/150
# 8000/8000 [==============================] - 0s 33us/step - loss: 2.5178e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0287 - val_mean_absolute_error: 0.1487
# Epoch 104/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.5427e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0268 - val_mean_absolute_error: 0.1415
# Epoch 105/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.4813e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0142 - val_mean_absolute_error: 0.0907
# Epoch 106/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.5684e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0219 - val_mean_absolute_error: 0.1246
# Epoch 107/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.4218e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0228 - val_mean_absolute_error: 0.1280
# Epoch 108/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.4806e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0231 - val_mean_absolute_error: 0.1293
# Epoch 109/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.5650e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0306 - val_mean_absolute_error: 0.1550
# Epoch 110/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.3869e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0208 - val_mean_absolute_error: 0.1196
# Epoch 111/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.4796e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0299 - val_mean_absolute_error: 0.1530
# Epoch 112/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.3695e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0165 - val_mean_absolute_error: 0.1002
# Epoch 113/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.5336e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0174 - val_mean_absolute_error: 0.1045
# Epoch 114/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.2716e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0281 - val_mean_absolute_error: 0.1465
# Epoch 115/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.4354e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0204 - val_mean_absolute_error: 0.1183
# Epoch 116/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.3051e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0164 - val_mean_absolute_error: 0.1005
# Epoch 117/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.4246e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0241 - val_mean_absolute_error: 0.1322
# Epoch 118/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.3657e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0175 - val_mean_absolute_error: 0.1051
# Epoch 119/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.2128e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0244 - val_mean_absolute_error: 0.1338
# Epoch 120/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.3304e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0215 - val_mean_absolute_error: 0.1225
# Epoch 121/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.2985e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0226 - val_mean_absolute_error: 0.1278
# Epoch 122/150
# 8000/8000 [==============================] - 0s 29us/step - loss: 2.2957e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0147 - val_mean_absolute_error: 0.0930
# Epoch 123/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.3669e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0286 - val_mean_absolute_error: 0.1487
# Epoch 124/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.2115e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0183 - val_mean_absolute_error: 0.1093
# Epoch 125/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.2158e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0239 - val_mean_absolute_error: 0.1320
# Epoch 126/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.3096e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0297 - val_mean_absolute_error: 0.1523
# Epoch 127/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.2560e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0188 - val_mean_absolute_error: 0.1110
# Epoch 128/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.3090e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0226 - val_mean_absolute_error: 0.1280
# Epoch 129/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.1866e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0189 - val_mean_absolute_error: 0.1123
# Epoch 130/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.1653e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0246 - val_mean_absolute_error: 0.1353
# Epoch 131/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.1438e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0259 - val_mean_absolute_error: 0.1402
# Epoch 132/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.2256e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0241 - val_mean_absolute_error: 0.1333
# Epoch 133/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.1789e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0253 - val_mean_absolute_error: 0.1382
# Epoch 134/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.3150e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0182 - val_mean_absolute_error: 0.1094
# Epoch 135/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.0923e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0219 - val_mean_absolute_error: 0.1241
# Epoch 136/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.1190e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0175 - val_mean_absolute_error: 0.1058
# Epoch 137/150
# 8000/8000 [==============================] - 0s 27us/step - loss: 2.1893e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0141 - val_mean_absolute_error: 0.0908
# Epoch 138/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.0575e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0249 - val_mean_absolute_error: 0.1369
# Epoch 139/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.1031e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0235 - val_mean_absolute_error: 0.1313
# Epoch 140/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.0869e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0297 - val_mean_absolute_error: 0.1531
# Epoch 141/150
# 8000/8000 [==============================] - 0s 32us/step - loss: 2.1395e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0326 - val_mean_absolute_error: 0.1627
# Epoch 142/150
# 8000/8000 [==============================] - 0s 31us/step - loss: 2.0997e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0163 - val_mean_absolute_error: 0.1002
# Epoch 143/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.0484e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0170 - val_mean_absolute_error: 0.1031
# Epoch 144/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.0095e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0204 - val_mean_absolute_error: 0.1191
# Epoch 145/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.1006e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0277 - val_mean_absolute_error: 0.1465
# Epoch 146/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.0676e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0215 - val_mean_absolute_error: 0.1240
# Epoch 147/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.0016e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0316 - val_mean_absolute_error: 0.1594
# Epoch 148/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.0563e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0269 - val_mean_absolute_error: 0.1434
# Epoch 149/150
# 8000/8000 [==============================] - 0s 30us/step - loss: 2.0011e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0232 - val_mean_absolute_error: 0.1303
# Epoch 150/150
# 8000/8000 [==============================] - 0s 28us/step - loss: 2.1154e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0169 - val_mean_absolute_error: 0.1025

# %% [markdown]
# ### And now even a more complex one
#
# Let's try to predict now this function:
#
# $\displaystyle y = \cos(x)$
